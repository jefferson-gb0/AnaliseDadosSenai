# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tabela = pd.read_csv('banco.csv',';',encoding = 'ISO-8859-1')
tabela
# Out:
# /tmp/ipykernel_85/1795231181.py:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   tabela = pd.read_csv('banco.csv',';',encoding = 'ISO-8859-1')
#       data_entrada_brasil data_cadastro dif_dtcad_dtingr_meses       sexo  \
# 0              09/09/2012    27/05/2016                     44  Masculino
# 1              16/06/2015    31/05/2017                     23  Masculino
# 2              05/03/2010    19/03/2018                     96  Masculino
# 3              25/07/2012    27/11/2018                     76  Masculino
# 4              10/10/2008    10/01/2019                    123  Masculino
# ...                   ...           ...                    ...        ...
# 13328          18/04/2018    17/03/2020                     22  Masculino
# 13329          14/04/2014    17/03/2020                     71   Feminino
# ...

# %%
df = pd.DataFrame(tabela)
df
# Out:
#       data_entrada_brasil data_cadastro dif_dtcad_dtingr_meses       sexo  \
# 0              09/09/2012    27/05/2016                     44  Masculino
# 1              16/06/2015    31/05/2017                     23  Masculino
# 2              05/03/2010    19/03/2018                     96  Masculino
# 3              25/07/2012    27/11/2018                     76  Masculino
# 4              10/10/2008    10/01/2019                    123  Masculino
# ...                   ...           ...                    ...        ...
# 13328          18/04/2018    17/03/2020                     22  Masculino
# 13329          14/04/2014    17/03/2020                     71   Feminino
# 13330          14/04/2014    17/03/2020                     71  Masculino
# 13331          08/03/2020    18/03/2020                      0   Feminino
# 13332          18/02/2020    18/03/2020                      1  Masculino
#
#                 fx_etaria    pais_origem distrito_moradia  \
# ...

# %%
df1 = pd.DataFrame(df)
df
# Out:
#       data_entrada_brasil data_cadastro dif_dtcad_dtingr_meses       sexo  \
# 0              09/09/2012    27/05/2016                     44  Masculino
# 1              16/06/2015    31/05/2017                     23  Masculino
# 2              05/03/2010    19/03/2018                     96  Masculino
# 3              25/07/2012    27/11/2018                     76  Masculino
# 4              10/10/2008    10/01/2019                    123  Masculino
# ...                   ...           ...                    ...        ...
# 13328          18/04/2018    17/03/2020                     22  Masculino
# 13329          14/04/2014    17/03/2020                     71   Feminino
# 13330          14/04/2014    17/03/2020                     71  Masculino
# 13331          08/03/2020    18/03/2020                      0   Feminino
# 13332          18/02/2020    18/03/2020                      1  Masculino
#
#                 fx_etaria    pais_origem distrito_moradia  \
# ...

# %%
df1 = df['fonte_renda']

display(font_rend)
# Out:
#                                              fonte_renda
# 0                                          Não informado
# 1                      Trabalhador informal ou ambulante
# 2      Empresário (MEI, dono de loja, restaurante, etc.)
# 3                      Trabalhador informal ou ambulante
# 4                      Trabalhador informal ou ambulante
# ...                                                  ...
# 13328                  Trabalhador informal ou ambulante
# 13329                  Trabalhador informal ou ambulante
# 13330                  Trabalhador informal ou ambulante
# 13331                  Trabalhador informal ou ambulante
# 13332                                             Outros
#
# [13333 rows x 1 columns]

# %%
font_rend = pd.DataFrame(df1)
display(font_rend)
# Out:
#                                              fonte_renda
# 0                                          Não informado
# 1                      Trabalhador informal ou ambulante
# 2      Empresário (MEI, dono de loja, restaurante, etc.)
# 3                      Trabalhador informal ou ambulante
# 4                      Trabalhador informal ou ambulante
# ...                                                  ...
# 13328                  Trabalhador informal ou ambulante
# 13329                  Trabalhador informal ou ambulante
# 13330                  Trabalhador informal ou ambulante
# 13331                  Trabalhador informal ou ambulante
# 13332                                             Outros
#
# [13333 rows x 1 columns]

# %%
font_rend['Pessoas']= '1'
display(font_rend)
# Out:
#                                              fonte_renda  $ Pessoas
# 0                                          Não informado  1       1
# 1                      Trabalhador informal ou ambulante  1       1
# 2      Empresário (MEI, dono de loja, restaurante, etc.)  1       1
# 3                      Trabalhador informal ou ambulante  1       1
# 4                      Trabalhador informal ou ambulante  1       1
# ...                                                  ... ..     ...
# 13328                  Trabalhador informal ou ambulante  1       1
# 13329                  Trabalhador informal ou ambulante  1       1
# 13330                  Trabalhador informal ou ambulante  1       1
# 13331                  Trabalhador informal ou ambulante  1       1
# 13332                                             Outros  1       1
#
# [13333 rows x 3 columns]

# %%
font_rend = font_rend.drop(columns=['$'])

# %%
agrupar = font_rend.groupby('fonte_renda').count()

# %%
display(agrupar)
# Out:
#                                                     Pessoas
# fonte_renda
# Benefícios sociais (BPC, Bolsa família, Auxílio...      230
# Desempregado                                           7150
# Empresário (MEI, dono de loja, restaurante, etc.)       215
# Não informado                                          2628
# Não respondeu                                             6
# Não se aplica - criança/ adolescente                    176
# Outros                                                  125
# Trabalhador CLT                                        1462
# Trabalhador autônomo                                    661
# Trabalhador informal ou ambulante                       680
